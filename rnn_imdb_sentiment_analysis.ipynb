# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
imdb = keras.datasets.imdb
(x_train,y_train),(x_test,y_test)=imdb.load_data(num_words=10000) #uses top 10000 words

#pad sequences to ensure uniform length
x_train = keras.preprocessing.sequence.pad_sequences(x_train,maxlen=100)
x_test = keras.preprocessing.sequence.pad_sequences(x_test,maxlen=100)
# Out:
# ...
# 17464789/17464789 [==============================] - 14s 1us/step

# %%
model = keras.Sequential([
    #embedding layer
    keras.layers.Embedding(input_dim=10000,output_dim=64,input_length=100),

    #LSTM layer
    keras.layers.LSTM(64,return_sequences=True),
    keras.layers.LSTM(32),

    #output layer
    keras.layers.Dense(1,activation='sigmoid')  #We are doing binary classification(positive/negative)
])

# %%
model.compile(optimizer='adam',
             loss = 'binary_crossentropy',
             metrics = ['accuracy'])

# %%
model.fit(x_train,y_train,epochs=5,batch_size=64,validation_data=(x_test,y_test))
test_loss,test_acc=model.evaluate(x_test,y_test)
print("Accuracy: ",test_acc)
# Out:
# Epoch 1/5
# 391/391 [==============================] - 106s 253ms/step - loss: 0.4188 - accuracy: 0.7972 - val_loss: 0.3449 - val_accuracy: 0.8502
# Epoch 2/5
# 391/391 [==============================] - 97s 247ms/step - loss: 0.2648 - accuracy: 0.8936 - val_loss: 0.3806 - val_accuracy: 0.8312
# Epoch 3/5
# 391/391 [==============================] - 95s 243ms/step - loss: 0.1986 - accuracy: 0.9246 - val_loss: 0.4010 - val_accuracy: 0.8424
# Epoch 4/5
# 391/391 [==============================] - 103s 262ms/step - loss: 0.1396 - accuracy: 0.9497 - val_loss: 0.4679 - val_accuracy: 0.8287
# Epoch 5/5
# ...
# 782/782 [==============================] - 34s 44ms/step - loss: 0.4946 - accuracy: 0.8232
# Accuracy:  0.8232399821281433

# %%
#predict sentiment for the first review
prediction = model.predict(x_test)
for ans in prediction:
    print("Prediction: ", "Positive" if ans>0.5 else "Negative")
# Out:
# 782/782 [==============================] - 34s 44ms/step
# Prediction:  Negative
# Prediction:  Positive
# Prediction:  Positive
# Prediction:  Negative
# Prediction:  Positive
# Prediction:  Positive
# Prediction:  Positive
# Prediction:  Negative
# Prediction:  Positive
# Prediction:  Positive
# Prediction:  Positive
# Prediction:  Negative
# Prediction:  Negative
# Prediction:  Negative
# Prediction:  Positive
# Prediction:  Negative
# Prediction:  Positive
# Prediction:  Negative
# Prediction:  Negative
# Prediction:  Negative
# Prediction:  Positive
# Prediction:  Positive
# Prediction:  Negative
# Prediction:  Positive
# Prediction:  Positive
# Prediction:  Positive
# Prediction:  Negative
# Prediction:  Positive
# Prediction:  Positive
# Prediction:  Negative
# Prediction:  Positive
# Prediction:  Negative
# Prediction:  Negative
# Prediction:  Negative
# Prediction:  Negative
# Prediction:  Negative
# Prediction:  Positive
# Prediction:  Positive
# Prediction:  Positive
# ...
